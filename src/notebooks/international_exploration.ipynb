# %% [markdown]
# ## International COVID Data Exploration
#
# In this notebook, we explore international COVID data from various sources

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_vacc = pd.read_csv("../../data/owid/owid-covid-data.csv")

# %%
df_vacc.total_vaccinations_per_hundred
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
df_stringency = df_vacc.groupby("location", as_index=False)["stringency_index"]
df_stringency.first()
# Out:
#               location  stringency_index
# 0          Afghanistan              8.33
# 1               Africa               NaN
# 2              Albania              8.33
# 3              Algeria              0.00
# 4              Andorra              0.00
# ..                 ...               ...
# 233  Wallis and Futuna               NaN
# 234              World               NaN
# 235              Yemen             61.11
# 236             Zambia             16.67
# 237           Zimbabwe             27.78
#
# [238 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 5), dpi=100)

sns.lineplot(
    data=df_vacc,
    x="date",
    y="total_vaccinations_per_hundred",
    hue="continent",
    ci=None,
)

# ax.set(xlabel="Timeline", ylabel="Percent Fully Vaccinated")
# ax.set(title="Proportion of Population Fully Vaccinated By Vaccine Mandates")
# plt.xticks(rotation=45)
# Out:
# <AxesSubplot:xlabel='date', ylabel='total_vaccinations_per_hundred'>
